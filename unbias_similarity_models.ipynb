# %% [markdown]
# <a href="https://colab.research.google.com/github/Un-bias/tag-based-music-retrieval/blob/master/unbias_similarity_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tag Based Music Retrieval - Evaluation

# %%
#@title Install packages and download code
# !pip install fire
# !pip install torch==1.6.0
# !pip install pytorch-lightning==0.9.0
# !pip install torchtext==0.8.1
# !pip install youtube_dl # Library to download youtube videos

# %cd /content
# !git clone https://github.com/chentinghao/download_google_drive.git
# %cd /content/download_google_drive/

# Taken from https://drive.google.com/drive/folders/1Y_XY4vdiVvqvEoe3HQcDx3wawBEgsl0o
# and https://drive.google.com/drive/u/0/folders/1zt_CZqD6zP9OSDGTfk4MIQNDsJW_GbxM

downloads = [("music_w2v.tar.gz", "18vSbJndJ9poywbLtymiptq3xZkidpcN-"),
             ("music_emb.pkl", "1SHS1jpsoQjK8fnxHGue8rHdgDQfYJM_i")]

for file_path, file_id in downloads:
  # !python download_gdrive.py $file_id $file_path
  # !mv $file_path /content

# !tar xvzf "/content/music_w2v.tar.gz" -C /content/

from IPython.display import clear_output 
# %cd /content/
# !git clone https://github.com/Un-bias/tag-based-music-retrieval.git
# %cd /content/tag-based-music-retrieval


clear_output()

# %% [markdown]
# ## Load model

# %%
checkpoint_dropbox_link = "https://www.dropbox.com/s/k9yfi76zuf5mm3e/top100_1000pslit_epoch%3D64.ckpt?dl=0" #@param {"type":"string"}
checkpoint_dropbox_link = "?".join(checkpoint_dropbox_link.split("?")[:-1])
checkpoint_dropbox_link = checkpoint_dropbox_link + "?dl=1"
# !wget -O /content/checkpoint.ckpt "$checkpoint_dropbox_link"

# %cd /content/tag-based-music-retrieval/train
from model import AudioModel
import numpy as np
import torch
import os
import numpy as np
import librosa
import pickle
from torch import nn
from gensim.models import Word2Vec

sr = 22050
input_length = 173
num_chunk = 16

def audio2spec(audio_path, n_mels=128, n_frames = 173, n_fft = 1024, hop_length = 512, sr = 22050):
    y, sample_rate = librosa.load(audio_path, mono=True, sr=sr)
    S = librosa.feature.melspectrogram(y = y, sr = sample_rate, n_mels=n_mels, n_fft = n_fft, hop_length=hop_length, fmax = 8000)
    S = librosa.power_to_db(S, ref = np.max)
    return S

def storage2npy(npy_path, google_storage_filepath):
    song_path = "audio.m4a"
    blob = bucket.get_blob(filepath)
    blob.download_to_filename(song_path)
    spec = audio2spec(song_path)
    with open(npy_path,'wb') as f:
        np.save(f, spec)

def m4a2npy(npy_path, m4a_path):
    spec = audio2spec(m4a_path)
    with open(npy_path,'wb') as f:
        np.save(f, spec)

def load_spec(npy_path):
    length = input_length
    spec = np.load(npy_path)

    # for short spectrograms
    if spec.shape[1] < input_length:
        nspec = np.zeros((128, input_length))
        nspec[:, :spec.shape[1]] = spec
        spec = nspec

    hop = (spec.shape[1] - input_length) // num_chunk
    spec = np.array([spec[:, i*hop:i*hop+input_length] for i in range(num_chunk)])
    return spec

def tags_to_emb(word_emb):
    tag_emb = model.word_to_embedding(word_emb).detach().cpu()
    return tag_emb

def tags2emb(tags):
  w2v_model = Word2Vec.load("/content/music_w2v/model_semeval_trigrams_300.model")
  w2v = w2v_model.wv
  tags_v = [w2v.get_vector(tag) for tag in tags]
  return tags_to_emb(torch.Tensor(tags_v))

def all_tags():
  emb_path = "/content/music_emb.pkl"
  emb_dict = pickle.load(open(emb_path, 'rb'))
  word_emb = torch.tensor([emb_dict[key] for key in emb_dict.keys()])
  tag_embs = tags_to_emb(word_emb)
  tags = emb_dict.keys()
  return tags, tag_embs

def get_similarity(tag_embs, song_embs):
    sim_scores = np.zeros((len(tag_embs), len(song_embs)))
    for i in range(len(tag_embs)):
        sim_scores[i] = np.array(nn.CosineSimilarity(dim=-1)(tag_embs[i], song_embs))
    return sim_scores

input_length = 173

model = AudioModel()
model_load_path = "/content/checkpoint.ckpt"
S = torch.load(model_load_path, map_location=torch.device('cpu'))['state_dict']
SS = {key[6:]: S[key] for key in S.keys()}
model.load_state_dict(SS)
# Out:
# --2021-05-14 16:54:53--  https://www.dropbox.com/s/k9yfi76zuf5mm3e/top100_1000pslit_epoch%3D64.ckpt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/k9yfi76zuf5mm3e/top100_1000pslit_epoch%3D64.ckpt [following]
# --2021-05-14 16:54:53--  https://www.dropbox.com/s/dl/k9yfi76zuf5mm3e/top100_1000pslit_epoch%3D64.ckpt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca0bb6929cf34adb8ecb8e8c4ac.dl.dropboxusercontent.com/cd/0/get/BOd7OQgpsLg7Dp0ihbQ3sVB6IcmktSNDNmUrKYrApy60oVMssr2dAgRf1QLLcOHQSDfPNDcE0ZCkglnJLhTXKxZtknKacWXa83bu2qyZ6u4dTNo4Ik8WrFs8YBqvSXVwUzDIbl3oM3TcMmXxBAD2_sev/file?dl=1# [following]
# --2021-05-14 16:54:53--  https://uca0bb6929cf34adb8ecb8e8c4ac.dl.dropboxusercontent.com/cd/0/get/BOd7OQgpsLg7Dp0ihbQ3sVB6IcmktSNDNmUrKYrApy60oVMssr2dAgRf1QLLcOHQSDfPNDcE0ZCkglnJLhTXKxZtknKacWXa83bu2qyZ6u4dTNo4Ik8WrFs8YBqvSXVwUzDIbl3oM3TcMmXxBAD2_sev/file?dl=1
# Resolving uca0bb6929cf34adb8ecb8e8c4ac.dl.dropboxusercontent.com (uca0bb6929cf34adb8ecb8e8c4ac.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uca0bb6929cf34adb8ecb8e8c4ac.dl.dropboxusercontent.com (uca0bb6929cf34adb8ecb8e8c4ac.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45867518 (44M) [application/binary]
# Saving to: ‘/content/checkpoint.ckpt’
#
# /content/checkpoint 100%[===================>]  43.74M  14.1MB/s    in 3.1s
#
# 2021-05-14 16:54:57 (14.1 MB/s) - ‘/content/checkpoint.ckpt’ saved [45867518/45867518]
#
# /content/tag-based-music-retrieval/train
# <All keys matched successfully>

# %% [markdown]
# ## Compute similarity on some song you like
# https://stats.stackexchange.com/questions/198810/interpreting-negative-cosine-similarity/446554
#
# Compare over all the tags and sort them by similarity

# %%
#@title Download song
import youtube_dl

def download_from_youtube(yt_url):
  ydl_opts = {
      'format': 'bestaudio/best',
      'postprocessors': [{
          'key': 'FFmpegExtractAudio',
          'preferredcodec': 'mp3',
          'preferredquality': '192',
      }],
  }

  with youtube_dl.YoutubeDL(ydl_opts) as ydl:
      ydl.download([yt_url])
      info = ydl.extract_info(yt_url, download=True)
      filename = ydl.prepare_filename(info)
  return filename

youtube_link = "https://www.youtube.com/watch?v=Wc5IbN4xw70" #@param {"type":"string"}
filename = download_from_youtube(youtube_link)
# Out:
# [youtube] Wc5IbN4xw70: Downloading webpage
# [download] Destination: Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.m4a
# [download] 100% of 2.90MiB in 00:00
# [ffmpeg] Correcting container in "Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.m4a"
# [ffmpeg] Destination: Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.mp3
# Deleting original file Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.m4a (pass -k to keep)
# [youtube] Wc5IbN4xw70: Downloading webpage
# [download] Destination: Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.m4a
# [download] 100% of 2.90MiB in 00:00
# [ffmpeg] Correcting container in "Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.m4a"
# [ffmpeg] Destination: Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.mp3
# Deleting original file Cardi B - WAP feat. Megan Thee Stallion [Official Audio]-Wc5IbN4xw70.m4a (pass -k to keep)

# %%
#@title Compute similarity
filename = ".".join(filename.split(".")[:-1]) + ".mp3"
npy_path = "/content/test.npy"
m4a2npy(npy_path, filename)
spec = load_spec(npy_path)

song_embs = model.spec_to_embedding(torch.Tensor(spec))
song_embs = song_embs.detach().cpu()

tags, tag_embs = all_tags()
similarity = zip(tags,get_similarity(tag_embs, song_embs).mean(axis=1))

print("SIMILARITY\tTAG")
for tag, score in sorted(similarity, key=lambda x : x[1], reverse=True):
  print(f"{round(score,3)}\t\t{tag}")
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# SIMILARITY	TAG
# 0.131		progressive_rock
# 0.123		pop-rock
# 0.113		indie_pop
# 0.11		indie-rock
# 0.109		modern_rock
# 0.107		k-pop
# 0.105		alternative_rock
# 0.102		indie-pop
# 0.102		indie_rock
# 0.099		new-wave
# 0.098		post_punk
# 0.093		teen-pop
# 0.091		garage_rock
# 0.09		pop-punk
# 0.089		post-teen
# 0.088		garage-rock
# 0.086		folk-pop
# 0.086		art-rock
# 0.085		alternative_country
# 0.084		singer-songwriter
# 0.084		latin_alternative
# 0.083		new_wave
# 0.082		teen_pop
# 0.082		south_african
# 0.08		dance-pop
# 0.077		pop_punk
# 0.076		soft-rock
# 0.076		freak_folk
# 0.073		trip_hop
# 0.073		folk-rock
# 0.072		singer_songwriter
# 0.072		blues-rock
# 0.069		post_rock
# 0.069		jazz_fusion
# 0.069		bossa_nova
# 0.069		latin_pop
# 0.068		chamber_pop
# 0.067		acid_jazz
# 0.067		modern-rock
# 0.067		dance-rock
# 0.066		hip-hop
# 0.066		psychedelic_rock
# 0.066		urban_contemporary
# 0.061		chamber-pop
# 0.06		neo_soul
# 0.059		post_hardcore
# 0.058		soft_rock
# 0.057		tropical_house
# 0.052		regional_mexican
# 0.051		hip_hop
# 0.051		pop-rap
# 0.051		hard_rock
# 0.051		neo_psychedelic
# 0.05		alternative_metal
# 0.047		mellow_gold
# 0.047		funk_carioca
# 0.047		latin-pop
# 0.046		underground_hip
# 0.046		classic-rock
# 0.045		cloud_rap
# 0.044		post_grunge
# 0.043		bubblegum_pop
# 0.042		alternative-rock
# 0.037		progressive_house
# 0.029		dirty_south
# 0.029		electro-house
# 0.028		gangster_rap
# 0.027		boom_bap
# 0.027		quiet_storm
# 0.026		electro_house
# 0.024		adult_standards
# 0.023		hard-rock
# 0.021		power_metal
# 0.018		progressive_metal
# 0.018		deep_house
# 0.017		uplifting_trance
# 0.015		doom_metal
# 0.015		gangster-rap
# 0.013		progressive_trance
# 0.01		disco-house
# 0.009		tech_house
# 0.008		minimal_techno
# 0.007		tech-house
# 0.007		brill_building
# 0.004		east_coast
# 0.003		west_coast
# 0.002		old_school
# -0.005		big-room
# -0.006		euro_house
# -0.007		alternative-metal
# -0.011		speed_metal
# -0.013		death-metal
# -0.014		progressive-house
# -0.016		neo_classical
# -0.02		black_metal
# -0.023		thrash_metal
# -0.026		minimal_tech
# -0.029		death_metal
# -0.032		progressive-trance
# -0.037		black-metal

# %%
#@title Compute the similarity to specific words
song_embs = model.spec_to_embedding(torch.Tensor(spec))
song_embs = song_embs.detach().cpu()

tags = ["workout", "morning"] #@param
similarity = zip(tags, get_similarity(tags2emb(tags), song_embs).mean(axis=1))

print("SIMILARITY\tTAG")
for tag, score in sorted(similarity, key=lambda x : x[1], reverse=True):
  print(f"{round(score,3)}\t\t{tag}")
# Out:
# SIMILARITY	TAG
# 0.138		morning
# 0.086		workout

# %% [markdown]
# ## OLD STUFF, IGNORE THIS
# Looking for tags in the embedding

# %% [markdown]
# - https://github.com/minzwon/tag-based-music-retrieval
# - https://github.com/Un-bias/tag-based-music-retrieval
#
# - Other references
#   - https://github.com/google-research/leaf-audio
#   - https://github.com/andrebola/contrastive-mir-learning
#   - https://arxiv.org/pdf/2104.00437.pdf

# %%
w2v_model = Word2Vec.load("/content/music_w2v/model_semeval_trigrams_300.model")
w2v = w2v_model.wv

tags = ["rock", "indie-pop", "brazilian-indie-cumbia"]

valid = []
invalid = []

for tag in tags:
  try:
    w2v.get_vector(tag)
    valid.append(tag)
  except:
    invalid.append(tag)


print(f"VALID: {valid}")
print(f"INVALID: {invalid}")
# Out:
# VALID: ['rock', 'indie-pop']
# INVALID: ['brazilian-indie-cumbia']

# %%
import pandas as pd
df = pd.read_csv("/content/tag_count.csv")
print(len(df))
df = df[df["count"] > 200]
df["tags2"] = df["tags"].apply(lambda tag : tag.replace(" ","_"))
df["tags"] = df["tags"].apply(lambda tag : tag.replace(" ","-"))
our_tags = set(df["tags"].values.tolist())
our_tags2 = set(df["tags2"].values.tolist())
our_tags = our_tags | our_tags2
# Out:
# 4630

# %%
vocab = w2v.vocab.keys()
vocab = list(vocab)
their_tags = set(vocab)

# %%
len(their_tags)
# Out:
# 564886

# %%
len(df)
# Out:
# 1862

# %%
intersection = our_tags & their_tags
print(len(intersection))
pd.DataFrame({"tags":list(intersection)}).to_csv("/content/tags.csv",index=False)
# Out:
# 716

# %%
intersection
# Out:
# {'21st-century',
#  '21st_century',
#  'acid-house',
#  'acid-jazz',
#  'acid-techno',
#  'acid_house',
#  'acid_jazz',
#  'acid_techno',
#  'acoustic-blues',
#  'acoustic-guitar',
#  'acoustic-pop',
#  'acoustic_guitar',
#  'adult_standards',
#  'afro-house',
#  'alternative-country',
#  'alternative-dance',
#  'alternative-metal',
#  'alternative-pop',
#  'alternative-rap',
#  'alternative-rock',
#  'alternative_country',
#  'alternative_metal',
#  'alternative_rock',
#  'ambient-folk',
#  'ambient-techno',
#  'ambient_idm',
#  'ambient_techno',
#  'american-folk',
#  'american_folk',
#  'anglican_liturgy',
#  'ann_arbor',
#  'anti-folk',
#  'appalachian_folk',
#  'argentine_rock',
#  'armenian_folk',
#  'art-pop',
#  'art-rock',
#  'atmospheric_black',
#  'atmospheric_sludge',
#  'avant-garde',
#  'avant_garde',
#  'background-music',
#  'balkan_brass',
#  'ballet_class',
#  'baroque-pop',
#  'baroque_ensemble',
#  'baroque_pop',
#  'baton_rouge',
#  'battle-rap',
#  'battle_rap',
#  'bay-area',
#  'bay_area',
#  'bedroom-pop',
#  'belly_dance',
#  'belo_horizonte',
#  'big-band',
#  'big-beat',
#  'big-room',
#  'black-death',
#  'black-metal',
#  'black-thrash',
#  'black_metal',
#  'bluegrass_gospel',
#  'blues-rock',
#  'bongo_flava',
#  'boogie-woogie',
#  'boogie_woogie',
#  'boom-bap',
#  'boom_bap',
#  'bossa-nova',
#  'bossa_nova',
#  'boy-band',
#  'boy-group',
#  'brass-band',
#  'brass_ensemble',
#  'brazilian_jazz',
#  'brazilian_thrash',
#  'brill_building',
#  'brit-funk',
#  'brit_funk',
#  'british-invasion',
#  'british_folk',
#  'british_indie',
#  'british_invasion',
#  'broken-beat',
#  'broken_beat',
#  'brutal-death',
#  'brutal_death',
#  'brutal_deathcore',
#  'bubblegum-pop',
#  'bubblegum_dance',
#  'bubblegum_pop',
#  'buffalo_ny',
#  'c-pop',
#  'canadian_folk',
#  'canadian_indie',
#  'candy-pop',
#  'cante_flamenco',
#  'canterbury_scene',
#  'canzone_napoletana',
#  'cape_town',
#  'celtic-punk',
#  'celtic-rock',
#  'celtic_punk',
#  'chamber-pop',
#  'chamber_choir',
#  'chamber_orchestra',
#  'chamber_pop',
#  'chaotic_hardcore',
#  'charlotte_nc',
#  'chicago-house',
#  'chicago_blues',
#  'chicago_house',
#  'chicano_rap',
#  'chill_lounge',
#  'christian-metal',
#  'christian-music',
#  'christian-pop',
#  'christian-rock',
#  'classic-rock',
#  'classical-guitar',
#  'classical_piano',
#  'cloud_rap',
#  'coast_rap',
#  'contemporary_classical',
#  'contemporary_gospel',
#  'contemporary_jazz',
#  'cool-jazz',
#  'country-blues',
#  'country-gospel',
#  'country-pop',
#  'country-rap',
#  'country-rock',
#  'crossover-thrash',
#  'crossover_thrash',
#  'crust-punk',
#  'crust_punk',
#  'cuban_rumba',
#  'cumbia_villera',
#  'cyber-metal',
#  'cyber_metal',
#  'czech_folk',
#  'dance-music',
#  'dance-pop',
#  'dance-punk',
#  'dance-rock',
#  'danish_indie',
#  'danish_singer',
#  'dark-ambient',
#  'dark-wave',
#  'dark_ambient',
#  'dark_cabaret',
#  'dark_wave',
#  'de_la',
#  'death-metal',
#  'death_metal',
#  'deep-funk',
#  'deep-groove',
#  'deep-house',
#  'deep_house',
#  'delta-blues',
#  'delta_blues',
#  'denton_tx',
#  'depressive_black',
#  'desert-blues',
#  'detroit-techno',
#  'detroit_techno',
#  'deutsche_welle',
#  'dirty-south',
#  'dirty_south',
#  'disco-house',
#  'disco-polo',
#  'disco_polo',
#  'doo-wop',
#  'doo_wop',
#  'doom-metal',
#  'doom_metal',
#  'double-bass',
#  'double_bass',
#  'dream-pop',
#  'drone-folk',
#  'drone-metal',
#  'drum-bass',
#  'dub-reggae',
#  'dub-techno',
#  'dub_reggae',
#  'dub_techno',
#  'dutch_cabaret',
#  'early-music',
#  'east-coast',
#  'east_anglia',
#  'east_coast',
#  'easy-listening',
#  'easy_listening',
#  'eau_claire',
#  'el_paso',
#  'electric-blues',
#  'electric_bass',
#  'electric_blues',
#  'electro-dub',
#  'electro-house',
#  'electro-industrial',
#  'electro-jazz',
#  'electro-swing',
#  'electro_dub',
#  'electro_house',
#  'electro_industrial',
#  'electro_swing',
#  'electronic-rock',
#  'emo-punk',
#  'en_espanol',
#  'english_baroque',
#  'epic_doom',
#  'ethereal_wave',
#  'ethio-jazz',
#  'euro_house',
#  'experimental-ambient',
#  'experimental-pop',
#  'experimental-rock',
#  'experimental_ambient',
#  'experimental_electronic',
#  'fallen_angel',
#  'fidget_house',
#  'flamenco_guitar',
#  'folk-metal',
#  'folk-pop',
#  'folk-punk',
#  'folk-revival',
#  'folk-rock',
#  'folk_revival',
#  'fourth-world',
#  'freak-folk',
#  'freak_folk',
#  'free-improvisation',
#  'free-jazz',
#  'free_improvisation',
#  'free_jazz',
#  'french-pop',
#  'french_baroque',
#  'funeral_doom',
#  'funk-metal',
#  'funk-rock',
#  'funk_carioca',
#  'funky_breaks',
#  'future-garage',
#  'future_garage',
#  'g-funk',
#  'g_funk',
#  'game-music',
#  'gangsta-rap',
#  'gangsta_rap',
#  'gangster-rap',
#  'gangster_rap',
#  'garage-pop',
#  'garage-psych',
#  'garage-punk',
#  'garage-rock',
#  'garage_psych',
#  'garage_punk',
#  'garage_rock',
#  'german-punk',
#  'german_thrash',
#  'girl-group',
#  'glam-metal',
#  'glam-rock',
#  'glam_metal',
#  'glam_rock',
#  'glitch-hop',
#  'glitch_hop',
#  'gothenburg_metal',
#  'gothic-metal',
#  'gothic-rock',
#  'gothic_metal',
#  'gothic_rock',
#  'grand_rapids',
#  'groove-metal',
#  'gypsy-jazz',
#  'gypsy-punk',
#  'gypsy_jazz',
#  'gypsy_punk',
#  'hamburger_schule',
#  'hammond-organ',
#  'hammond_organ',
#  'happy-hardcore',
#  'hard-bop',
#  'hard-rock',
#  'hard_bop',
#  'hard_rock',
#  'hardcore-punk',
#  'hardcore-techno',
#  'hardcore_punk',
#  'hardcore_techno',
#  'heartland_rock',
#  'heavy-metal',
#  'heavy_metal',
#  'hi-nrg',
#  'hip-hop',
#  'hip-house',
#  'hip-pop',
#  'hip_hop',
#  'hip_house',
#  'historically-informed',
#  'historically_informed',
#  'hong-kong',
#  'hong_kong',
#  'honky-tonk',
#  'honky_tonk',
#  'horror-punk',
#  'horror_punk',
#  'hungarian_underground',
#  'hurdy-gurdy',
#  'hurdy_gurdy',
#  'indian-pop',
#  'indian_classical',
#  'indie-electronica',
#  'indie-folk',
#  'indie-garage',
#  'indie-pop',
#  'indie-punk',
#  'indie-rock',
#  'indie_folk',
#  'indie_pop',
#  'indie_rock',
#  'indo-pop',
#  'industrial-metal',
#  'industrial-rock',
#  'industrial-techno',
#  'industrial_metal',
#  'industrial_techno',
#  'instrumental-rock',
#  'irish-folk',
#  'irish-pop',
#  'irish_folk',
#  'italian_opera',
#  'italian_progressive',
#  'italo_dance',
#  'j-core',
#  'j-metal',
#  'j-pop',
#  'j-rap',
#  'j-rock',
#  'jack_swing',
#  'jam-band',
#  'jangle-pop',
#  'jangle_pop',
#  'japanese_shoegaze',
#  'jazz-blues',
#  'jazz-funk',
#  'jazz-fusion',
#  'jazz-guitar',
#  'jazz-metal',
#  'jazz-piano',
#  'jazz-rap',
#  'jazz-trumpet',
#  'jazz_funk',
#  'jazz_fusion',
#  'jersey_club',
#  'jovem_guarda',
#  'jump-blues',
#  'jump_blues',
#  'k-indie',
#  'k-pop',
#  'kawaii_metal',
#  'kindie_rock',
#  'korean_pop',
#  'la_plata',
#  'late-romantic',
#  'latin-funk',
#  'latin-jazz',
#  'latin-pop',
#  'latin-rock',
#  'latin_alternative',
#  'latin_jazz',
#  'latin_pop',
#  'liquid_funk',
#  'lithuanian_pop',
#  'lo-fi',
#  'lo_fi',
#  'lovers-rock',
#  'luk_thung',
#  'math-pop',
#  'math-rock',
#  'math_rock',
#  'medieval_folk',
#  'mellow_gold',
#  'melodic-death',
#  'melodic-hard',
#  'melodic-hardcore',
#  'melodic-progressive',
#  'melodic-punk',
#  'melodic_death',
#  'melodic_hardcore',
#  'melodic_metalcore',
#  'memphis-soul',
#  'memphis_blues',
#  'memphis_soul',
#  'merengue_tipico',
#  'metallic_hardcore',
#  'mezzo-soprano',
#  'mezzo_soprano',
#  'miami_bass',
#  'middle-earth',
#  'middle_earth',
#  'midwest_emo',
#  'minimal-tech',
#  'minimal-techno',
#  'minimal-wave',
#  'minimal_tech',
#  'minimal_techno',
#  'minimal_wave',
#  'mod-revival',
#  'mod_revival',
#  'modern-classical',
#  'modern-jazz',
#  'modern-rock',
#  'modern_rock',
#  'musica_de',
#  'musique_concrete',
#  'n_roll',
#  'native-american',
#  'native_american',
#  'neo-classical',
#  'neo-progressive',
#  'neo-psychedelic',
#  'neo-soul',
#  'neo-trad',
#  'neo-traditional',
#  'neo_classical',
#  'neo_progressive',
#  'neo_psychedelic',
#  'neo_soul',
#  'neue_deutsche',
#  'new-age',
#  'new-jack',
#  'new-orleans',
#  'new-romantic',
#  'new-wave',
#  'new_age',
#  'new_jersey',
#  'new_orleans',
#  'new_wave',
#  'noise-pop',
#  'noise-rock',
#  'nordic_folk',
#  'north-carolina',
#  'north-east',
#  'north_carolina',
#  'north_east',
#  'northern-soul',
#  'northern_irish',
#  'northern_soul',
#  'norwegian_black',
#  'nu-age',
#  'nu-disco',
#  'nu-gaze',
#  'nu-jazz',
#  'nu-metal',
#  'nu-skool',
#  'nu_disco',
#  'nu_jazz',
#  'nu_metal',
#  'nu_skool',
#  'nueva_cancion',
#  'nueva_trova',
#  'nuevo_tango',
#  'old-school',
#  'old-time',
#  'old_school',
#  'olympia_wa',
#  'one-person',
#  'organic-electronic',
#  'oshare_kei',
#  'outlaw_country',
#  'p-funk',
#  'p_funk',
#  'pagan_black',
#  'palm_desert',
#  'pan_alley',
#  'philly-soul',
#  'philly_soul',
#  'piano-rock',
#  'piedmont_blues',
#  'pinoy_rock',
#  'polish_reggae',
#  'pop-emo',
#  'pop-flamenco',
#  'pop-folk',
#  'pop-house',
#  'pop-punk',
#  'pop-rap',
#  'pop-rock',
#  'pop_punk',
#  'post-black',
#  'post-bop',
#  'post-disco',
#  'post-doom',
#  'post-grunge',
#  'post-hardcore',
#  'post-metal',
#  'post-post',
#  'post-punk',
#  'post-rock',
#  'post-romantic',
#  'post-screamo',
#  'post-teen',
#  'post_bop',
#  'post_grunge',
#  'post_hardcore',
#  'post_punk',
#  'post_rock',
#  'power-blues',
#  'power-metal',
#  'power-pop',
#  'power_metal',
#  'power_pop',
#  'progressive-house',
#  'progressive-metal',
#  'progressive-rock',
#  'progressive-sludge',
#  'progressive-trance',
#  'progressive_bluegrass',
#  'progressive_deathcore',
#  'progressive_house',
#  'progressive_metal',
#  'progressive_metalcore',
#  'progressive_psytrance',
#  'progressive_rock',
#  'progressive_sludge',
#  'progressive_trance',
#  'psych-pop',
#  'psychedelic-folk',
#  'psychedelic-rock',
#  'psychedelic-trance',
#  'psychedelic_folk',
#  'psychedelic_rock',
#  'psychedelic_trance',
#  'pub-rock',
#  'pub_rock',
#  'puerto-rican',
#  'puerto_rican',
#  'punk-blues',
#  'punk-rock',
#  'punk_rock',
#  'quiet-storm',
#  'quiet_storm',
#  'ragga-jungle',
#  'ragga_jungle',
#  'rap-metal',
#  'rap-rock',
#  'rare-groove',
#  'rare_groove',
#  'red-dirt',
#  'red_dirt',
#  'reggae-fusion',
#  'reggae-rock',
#  'reggae_fusion',
#  'regional_mexican',
#  'retro-electro',
#  'retro-metal',
#  'retro-soul',
#  'rhode_island',
#  'rio_de',
#  'riot-grrrl',
#  'riot_grrrl',
#  'rock-roll',
#  'rock-steady',
#  'rock_alternativo',
#  'rock_nacional',
#  'rock_steady',
#  'romantic-era',
#  'roots-reggae',
#  'roots-rock',
#  'roots_reggae',
#  'russian_alternative',
#  'salsa_cubana',
#  'san-diego',
#  'san_diego',
#  'san_marcos',
#  'sci-fi',
#  'sci_fi',
#  'scottish_folk',
#  'scottish_indie',
#  'shibuya-kei',
#  'show-tunes',
#  'singer-songwriter',
#  'singer_songwriter',
#  'ska-jazz',
#  'ska-punk',
#  'ska-revival',
#  'ska_punk',
#  'ska_revival',
#  'skate-punk',
#  'skate_punk',
#  'skool_breaks',
#  'slam_death',
#  'slam_poetry',
#  'sleaze_rock',
#  'slow-core',
#  'sludge-metal',
#  'sludge_metal',
#  'smooth-jazz',
#  'smooth_jazz',
#  'social_media',
#  'soft-rock',
#  'soft_rock',
#  'soul-blues',
#  'soul-house',
#  'soul-jazz',
#  'sound-art',
#  'south-african',
#  'south_african',
#  'south_carolina',
#  'southern-gospel',
#  'southern-rock',
#  'southern_gospel',
#  'southern_rock',
#  'southern_soul',
#  'space-age',
#  'space-disco',
#  'space-rock',
#  'space_age',
#  'space_disco',
#  'spanish-folk',
#  'speed-garage',
#  'speed-metal',
#  'speed_garage',
#  'speed_metal',
#  'stoner-metal',
#  'stoner-rock',
#  'stoner_metal',
#  'stoner_rock',
#  'straight-edge',
#  'straight_edge',
#  'string-quartet',
#  'string_quartet',
#  'sunshine-pop',
#  'surf-music',
#  'swamp-pop',
#  'swamp_pop',
#  'swedish_death',
#  'swedish_eurodance',
#  'swedish_idol',
#  'swedish_punk',
#  'swedish_singer',
#  'swedish_synthpop',
#  'symphonic_black',
#  'symphonic_metal',
#  'symphonic_power',
#  'symphonic_rock',
#  'talent-show',
#  'tech-house',
#  'tech_house',
#  'technical-death',
#  'technical_brutal',
#  'technical_death',
#  'technical_deathcore',
#  'technical_thrash',
#  'teen-pop',
#  'teen_pop',
#  'tex-mex',
#  'tex_mex',
#  'texas-blues',
#  'texas_blues',
#  'thai_pop',
#  'thrash-core',
#  'thrash-metal',
#  'thrash_metal',
#  'tin-pan',
#  'tin_pan',
#  'torch-song',
#  'traditional_bluegrass',
#  'traditional_country',
#  'traditional_folk',
#  'tribal-house',
#  'tribal_house',
#  'trip-hop',
#  'trip_hop',
#  'tropical_house',
#  'turbo-folk',
#  'turbo_folk',
#  'turkish_folk',
#  'turkish_pop',
#  'turkish_singer',
#  'twee-pop',
#  'twee_pop',
#  'uk-dub',
#  'uk_garage',
#  'underground_hip',
#  'underground_rap',
#  'uplifting_trance',
#  'urban_contemporary',
#  'victoria_bc',
#  'video-game',
#  'video_game',
#  'viking-metal',
#  'viking_metal',
#  'visual-kei',
#  'visual_kei',
#  'vocal-harmony',
#  'vocal-house',
#  'vocal-jazz',
#  'vocal_harmony',
#  'voor_kinderen',
#  'wave-pop',
#  'west-coast',
#  'west_australian',
#  'west_coast',
#  'western-swing',
#  'western_swing',
#  'wind_ensemble',
#  'witch-house',
#  'witch_house',
#  'world-fusion',
#  'yacht_rock',
#  'ye-ye',
#  'ye_ye'}

# %%
import json
with open("/content/vocab.json",'w') as f:
  json.dump(vocab,f)
